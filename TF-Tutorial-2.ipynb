# %%
from PIL import Image
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
im = Image.open("/data/tutorial/stop_sign_jpg/14_00006_00017.jpg")

# %%
img=mpimg.imread('/data/tutorial/stop_sign_jpg/14_00006_00017.jpg')

# %%
implot = plt.imshow(img)

# %%
img.shape
# Out:
# (52, 49, 3)

# %%
img2=mpimg.imread('/data/tutorial/stop_sign_jpg/00002_00021.jpg')
implot2 = plt.imshow(img2)

# %%
img2.shape
# Out:
# (58, 58, 3)
